# %%
import requests
import demjson
import pandas as pd
import time
import datetime
import json
from sqlalchemy import create_engine

# %%
final_df=df

# %%
def Dump_mysql(final_df):
    connection_string = f"{'root'}:{'Ankitha@143'}@localhost:3306/{'suri'}?charset=utf8"
    #root =user name
    #Ankitha@143 =password
#     suri = Database name
#
            
    engine = create_engine(f'mysql://{connection_string}')

    # engine = create_engine("mysql://root:Ankitha@143@localhost/wallmart", echo=True)
    return final_df.to_sql('sensorsdata2', engine, if_exists='append', index=False)

# %%
# to read and write data into excel from database

from pymysql import*
import xlwt
import pandas.io.sql as sql
# connect the mysql with the python
con=connect(user="root",password="Ankitha@143",host="localhost",database="wallmart")
# read the data
df=sql.read_sql('select * from wall_mart_weekly_data',con)
# print the data
# print(df)
# export the data into the excel sheet
df.to_excel('ds.xlsx')
# Out:
# C:\Users\Karunakar\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:920: UserWarning: Ignoring URL 'https://grocery.walmart.com/v3/api/products/13439653?itemFields=all&storeId=2086' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\Karunakar\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:920: UserWarning: Ignoring URL 'https://grocery.walmart.com/v3/api/products/798350187?itemFields=all&storeId=2086' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\Karunakar\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:920: UserWarning: Ignoring URL 'https://grocery.walmart.com/v3/api/products/15550250?itemFields=all&storeId=2086' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# ...
